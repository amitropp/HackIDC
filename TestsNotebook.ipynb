# %%
import pandas as pd

# %%
PATH = 'C:\Users\itc_user1\Desktop\HackIDC'

# %%
# import orders
orders = pd.read_csv('{}/orders_english.csv'.format(PATH), encoding = 'hebrew')
orders.head
# Out:
# <bound method DataFrame.head of             order          customer_name  \
# 0     201018811-1             גיל בן אבו
# 1     201017870-1                בלה לוי
# 2     201018262-1               רחל מלסה
# 3     201018879-1                ארז בלס
# 4     201019280-1           רוגוטנר מנשה
# 5     201018151-1           איתן ברכוכבא
# 6     201019420-1               גד שמואל
# 7     201017079-1               מיקי מור
# 8     201017079-3               מיקי מור
# 9     201017079-5               מיקי מור
# 10    201019320-2                 ניסים
# 11    201017133-1                han bok
# 12    201018131-1                חנה  כץ
# 13    201019188-1             שלום שרעבי
# 14    201017476-1              tom mazon
# 15    201018611-1                   רחל
# 16    201018895-1               שחף שרון
# 17    201017656-1              עודד זהבי
# 18    201019237-1             אורטל מלכה
# 19    201019579-1           מתי זילברבוש
# 20    201016963-1              טופז סירי
# ...
